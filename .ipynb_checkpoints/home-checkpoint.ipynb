# %%
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import font_manager, rc

plt.rc("font", family = "Malgun Gothic")

### 그래프 내에 마이너스( - ) 표시 기호 적용하기
plt.rcParams["axes.unicode_minus"] = False

# %%
import numpy as np
# plotly 라이브러리 불러오기
import plotly.offline as pyo
import plotly.express as px
import plotly.graph_objs as go

# %%
#plotly 모듈을 초기화
pyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("./data/화력발전소_인근_미세먼지_정보202109.csv")
df
# Out:
#     therm_pwplant_no therm_pwplant_nm                therm_pwplant_addr  \
# 0                 21          태안화력발전소              충청남도 태안군 원북면 발전로 457
# 1                 28         남제주화력발전소      제주특별자치도 서귀포시 안덕면 해안로106번길 55
# 2                  5        대산복합화력발전소                충남 서산시 대산읍 독곶1로 82
# 3                 33           영흥발전본부        인천광역시 옹진군 영흥면 영흥남로293번길 75
# 4                 45          서천화력발전소           충청남도 서천시 서면 서인로235번길 85
# 5                 42          보령화력발전소          충청남도 보령시 오천면 오천해안로 89-37
# 6                 49         신보령화력발전소              충청남도 보령시 주교면 송도길 201
# 7                 37          당진화력발전소               충청남도 당진시 석문면 교로길 30
# 8                 46          제주화력발전소               제주특별자치도 제주시 원당로 133
# 9                 17       인천LNG복합발전소            인천광역시 서구 중봉대로405번길 314
# 10                43        인천복합화력발전소            인천광역시 서구 중봉대로405번길 411
# 11                23       서인천복합화력발전소                   인천광역시 서구 장도로 57
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   therm_pwplant_no       49 non-null     int64
#  1   therm_pwplant_nm       49 non-null     object
#  2   therm_pwplant_addr     49 non-null     object
#  3   therm_pwplant_fnds_ix  49 non-null     float64
#  4   wnty_fnds_ix           49 non-null     float64
#  5   therm_pwplant_fnds_rt  49 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.4+ KB

# %%
df.describe()
# Out:
#        therm_pwplant_no  therm_pwplant_fnds_ix  wnty_fnds_ix  \
# count          49.00000              49.000000  4.900000e+01
# mean           25.00000              16.867143  1.686700e+01
# std            14.28869               1.707998  1.076859e-14
# min             1.00000              13.369000  1.686700e+01
# 25%            13.00000              16.436000  1.686700e+01
# 50%            25.00000              16.615000  1.686700e+01
# 75%            37.00000              17.369000  1.686700e+01
# max            49.00000              23.120000  1.686700e+01
#
#        therm_pwplant_fnds_rt
# count              49.000000
# mean                0.999980
# std                 0.101238
# min                 0.793000
# 25%                 0.974000
# 50%                 0.985000
# 75%                 1.030000
# max                 1.371000

# %%
korea = {"therm_pwplant_no":"화력발전소번호", "therm_pwplant_nm":"화력발전소명", "therm_pwplant_addr":"화력발전소주소",
        "therm_pwplant_fnds_ix":"화력발전소미세먼지지수", "wnty_fnds_ix":"전국미세먼지지수", "therm_pwplant_fnds_rt":"화력발전소미세먼지율"}

# %%
df.rename(columns=korea,inplace=True)

# %%
df
# Out:
#     화력발전소번호      화력발전소명                           화력발전소주소  화력발전소미세먼지지수  \
# 0        21     태안화력발전소              충청남도 태안군 원북면 발전로 457       17.369
# 1        28    남제주화력발전소      제주특별자치도 서귀포시 안덕면 해안로106번길 55       16.523
# 2         5   대산복합화력발전소                충남 서산시 대산읍 독곶1로 82       18.466
# 3        33      영흥발전본부        인천광역시 옹진군 영흥면 영흥남로293번길 75       16.523
# 4        45     서천화력발전소           충청남도 서천시 서면 서인로235번길 85       17.317
# 5        42     보령화력발전소          충청남도 보령시 오천면 오천해안로 89-37       17.260
# 6        49    신보령화력발전소              충청남도 보령시 주교면 송도길 201       17.260
# 7        37     당진화력발전소               충청남도 당진시 석문면 교로길 30       16.523
# 8        46     제주화력발전소               제주특별자치도 제주시 원당로 133       16.806
# 9        17  인천LNG복합발전소            인천광역시 서구 중봉대로405번길 314       17.049
# 10       43   인천복합화력발전소            인천광역시 서구 중봉대로405번길 411       17.049
# 11       23  서인천복합화력발전소                   인천광역시 서구 장도로 57       16.688
# ...

# %%
pyo.iplot([{'x':df['화력발전소명'], 'y':df['전국미세먼지지수'], 'name': '전국미세먼지지수'},
           {'x':df['화력발전소명'], 'y':df['화력발전소미세먼지지수'], 'name': '화력발전소미세먼지지수'},
           {'x':df['화력발전소명'], 'y':df['화력발전소미세먼지율'], 'name': '화력발전소미세먼지율'}])

# %%
data = [
    {'x': df['화력발전소명'], 'y': df['전국미세먼지지수'], 'name': '전국미세먼지지수'},
    {'x': df['화력발전소명'], 'y': df['화력발전소미세먼지지수'], 'name': '화력발전소미세먼지지수'},
    {'x': df['화력발전소명'], 'y': df['화력발전소미세먼지율'], 'name': '화력발전소미세먼지율'}
]

layout = go.Layout(xaxis={'tickangle': 45})
fig = go.Figure(data=data, layout=layout)

pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ### 에너지부분 오염물질 배출량

# %%
df2 = pd.read_excel("./data/2020년_통합검색_배출량.xlsx",
              usecols="C:M")
df2
# Out:
#     Unnamed: 2 Unnamed: 3       Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 0          대분류        대분류              TSP          PM-2.5           PM-10
# 1     에너지산업 연소        무연탄       18150.7243      5501.93834      10563.7216
# 2     에너지산업 연소        유연탄    1882536.00228   1451566.24686   1822191.11539
# 3     에너지산업 연소       B-A유         13.27227         5.74817        10.60452
# 4     에너지산업 연소       B-C유      38834.38952     10474.46038     24261.59926
# 5     에너지산업 연소         경유       7461.07434       962.89413      6148.01742
# 6     에너지산업 연소         등유      17457.55016      5233.74347     14384.91268
# 7     에너지산업 연소        LPG       8192.23285      8192.23285      8192.23285
# 8     에너지산업 연소        LNG     904336.83188    904336.83188    904336.83188
# 9     에너지산업 연소       고형연료      46140.72419     34726.59513      42308.6963
# 10    에너지산업 연소         기타     140556.24992             NaN             NaN
# ...

# %%
df3=df2.rename(columns=df2.iloc[0])

# %%
df3
# Out:
#            대분류    대분류              TSP          PM-2.5           PM-10  \
# 1     에너지산업 연소    무연탄       18150.7243      5501.93834      10563.7216
# 2     에너지산업 연소    유연탄    1882536.00228   1451566.24686   1822191.11539
# 3     에너지산업 연소   B-A유         13.27227         5.74817        10.60452
# 4     에너지산업 연소   B-C유      38834.38952     10474.46038     24261.59926
# 5     에너지산업 연소     경유       7461.07434       962.89413      6148.01742
# 6     에너지산업 연소     등유      17457.55016      5233.74347     14384.91268
# 7     에너지산업 연소    LPG       8192.23285      8192.23285      8192.23285
# 8     에너지산업 연소    LNG     904336.83188    904336.83188    904336.83188
# 9     에너지산업 연소   고형연료      46140.72419     34726.59513      42308.6963
# 10    에너지산업 연소     기타     140556.24992             NaN             NaN
# 11      비산업 연소    무연탄     306000.03018    122247.01234    234702.02196
# 12      비산업 연소   B-A유      24664.14195     13813.08599     22617.01783
# ...

# %%
df3=df3.drop(0)

# %%
df3
# Out:
#            대분류    대분류              TSP          PM-2.5           PM-10  \
# 1     에너지산업 연소    무연탄       18150.7243      5501.93834      10563.7216
# 2     에너지산업 연소    유연탄    1882536.00228   1451566.24686   1822191.11539
# 3     에너지산업 연소   B-A유         13.27227         5.74817        10.60452
# 4     에너지산업 연소   B-C유      38834.38952     10474.46038     24261.59926
# 5     에너지산업 연소     경유       7461.07434       962.89413      6148.01742
# 6     에너지산업 연소     등유      17457.55016      5233.74347     14384.91268
# 7     에너지산업 연소    LPG       8192.23285      8192.23285      8192.23285
# 8     에너지산업 연소    LNG     904336.83188    904336.83188    904336.83188
# 9     에너지산업 연소   고형연료      46140.72419     34726.59513      42308.6963
# 10    에너지산업 연소     기타     140556.24992             NaN             NaN
# 11      비산업 연소    무연탄     306000.03018    122247.01234    234702.02196
# 12      비산업 연소   B-A유      24664.14195     13813.08599     22617.01783
# ...

# %%
df3.columns
# Out:
# Index(['대분류', '대분류', 'TSP', 'PM-2.5', 'PM-10', 'SOx', 'NOx', 'VOCs', 'NH3',
#        'CO', 'BC'],
#       dtype='object')

# %%
df3.columns.values[1] = '소분류'

# %%
df3
# Out:
#            대분류    소분류              TSP          PM-2.5           PM-10  \
# 1     에너지산업 연소    무연탄       18150.7243      5501.93834      10563.7216
# 2     에너지산업 연소    유연탄    1882536.00228   1451566.24686   1822191.11539
# 3     에너지산업 연소   B-A유         13.27227         5.74817        10.60452
# 4     에너지산업 연소   B-C유      38834.38952     10474.46038     24261.59926
# 5     에너지산업 연소     경유       7461.07434       962.89413      6148.01742
# 6     에너지산업 연소     등유      17457.55016      5233.74347     14384.91268
# 7     에너지산업 연소    LPG       8192.23285      8192.23285      8192.23285
# 8     에너지산업 연소    LNG     904336.83188    904336.83188    904336.83188
# 9     에너지산업 연소   고형연료      46140.72419     34726.59513      42308.6963
# 10    에너지산업 연소     기타     140556.24992             NaN             NaN
# 11      비산업 연소    무연탄     306000.03018    122247.01234    234702.02196
# 12      비산업 연소   B-A유      24664.14195     13813.08599     22617.01783
# ...

# %%
# pyo.iplot([{'x':df['화력발전소명'], 'y':df['전국미세먼지지수'], 'name': '전국미세먼지지수'},
           # {'x':df['화력발전소명'], 'y':df['화력발전소미세먼지지수'], 'name': '화력발전소미세먼지지수'},
           # {'x':df['화력발전소명'], 'y':df['화력발전소미세먼지율'], 'name': '화력발전소미세먼지율'}])

# %%
# 대분류별 그룹화
df3_group = df3.groupby(["대분류"],as_index = False)
df3_group

# %%
df3_group = df3_group.head(1)
df3_group
# Out:
#            대분류   소분류              TSP          PM-2.5           PM-10  \
# 1     에너지산업 연소   무연탄       18150.7243      5501.93834      10563.7216
# 11      비산업 연소   무연탄     306000.03018    122247.01234    234702.02196
# 21      제조업 연소   무연탄    5109449.35572   1548801.83702    2973699.5252
# 32        생산공정   NaN              NaN             NaN             NaN
# 34  에너지수송 및 저장   NaN              NaN             NaN             NaN
# 35     유기용제 사용   NaN              NaN             NaN             NaN
# 36     도로이동오염원    경유    3911398.63344   3598486.74388   3911398.63344
# 41    비도로이동오염원  B-A유          84215.1       76063.344         84215.1
# 48       폐기물처리   NaN     320604.43295    197545.61762    235586.88153
# 49          농업   NaN              NaN             NaN             NaN
# 50     기타 면오염원   NaN        873328.56      498668.328       554075.92
# 51        비산먼지   NaN  315954444.23818  16113568.94086  94612961.53106
# ...

# %%
df3_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1 to 52
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대분류     13 non-null     object
#  1   소분류     5 non-null      object
#  2   TSP     9 non-null      object
#  3   PM-2.5  9 non-null      object
#  4   PM-10   9 non-null      object
#  5   SOx     7 non-null      object
#  6   NOx     8 non-null      object
#  7   VOCs    10 non-null     object
#  8   NH3     10 non-null     object
#  9   CO      8 non-null      object
#  10  BC      9 non-null      object
# dtypes: object(11)
# memory usage: 1.2+ KB

# %%
df3_group.isnull()
# Out:
#       대분류    소분류    TSP  PM-2.5  PM-10    SOx    NOx   VOCs    NH3     CO  \
# 1   False  False  False   False  False  False  False  False  False  False
# 11  False  False  False   False  False  False  False  False  False  False
# 21  False  False  False   False  False  False  False  False  False  False
# 32  False   True   True    True   True   True   True   True  False   True
# 34  False   True   True    True   True   True   True  False   True   True
# 35  False   True   True    True   True   True   True  False   True   True
# 36  False  False  False   False  False  False  False  False  False  False
# 41  False  False  False   False  False  False  False  False  False  False
# 48  False   True  False   False  False  False  False  False  False  False
# 49  False   True   True    True   True   True   True   True  False   True
# 50  False   True  False   False  False   True  False  False  False  False
# 51  False   True  False   False  False   True   True   True   True   True
# ...

# %%
df3_group=df3_group.fillna(0)
df3_group
# Out:
#            대분류   소분류           TSP        PM-2.5         PM-10           SOx  \
# 1     에너지산업 연소   무연탄  1.815072e+04  5.501938e+03  1.056372e+04  1.454716e+06
# 11      비산업 연소   무연탄  3.060000e+05  1.222470e+05  2.347020e+05  5.253001e+06
# 21      제조업 연소   무연탄  5.109449e+06  1.548802e+06  2.973700e+06  4.796848e+06
# 32        생산공정     0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 34  에너지수송 및 저장     0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 35     유기용제 사용     0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 36     도로이동오염원    경유  3.911399e+06  3.598487e+06  3.911399e+06  1.310751e+05
# 41    비도로이동오염원  B-A유  8.421510e+04  7.606334e+04  8.421510e+04  2.732644e+05
# 48       폐기물처리     0  3.206044e+05  1.975456e+05  2.355869e+05  1.684762e+06
# 49          농업     0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50     기타 면오염원     0  8.733286e+05  4.986683e+05  5.540759e+05  0.000000e+00
# ...

# %%
df3_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1 to 52
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대분류     13 non-null     object
#  1   소분류     13 non-null     object
#  2   TSP     13 non-null     float64
#  3   PM-2.5  13 non-null     float64
#  4   PM-10   13 non-null     float64
#  5   SOx     13 non-null     float64
#  6   NOx     13 non-null     float64
#  7   VOCs    13 non-null     float64
#  8   NH3     13 non-null     float64
#  9   CO      13 non-null     float64
#  10  BC      13 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.2+ KB

# %%
# 대분류별
# pyo['대분류'].iplot(kind='hist',
#                           bins=20,
#                           xTitle='대분류',
#                           linecolor='gray',
#                           histnorm='percent',
#                           yTitle='Percentage(%)',
#                           title='연소 종류에 따른 오염물질 배출 현황')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 2
#       1 # 대분류별
# ----> 2 pyo['대분류'].iplot(kind='hist',
#       3                           bins=20,
#       4                           xTitle='대분류',
#       5                           linecolor='gray',
#       6                           histnorm='percent',
#       7                           yTitle='Percentage(%)',
#       8                           title='연소 종류에 따른 오염물질 배출 현황')
#
# TypeError: 'module' object is not subscriptable

# %%
df3
# Out:
#            대분류    소분류              TSP          PM-2.5           PM-10  \
# 1     에너지산업 연소    무연탄       18150.7243      5501.93834      10563.7216
# 2     에너지산업 연소    유연탄    1882536.00228   1451566.24686   1822191.11539
# 3     에너지산업 연소   B-A유         13.27227         5.74817        10.60452
# 4     에너지산업 연소   B-C유      38834.38952     10474.46038     24261.59926
# 5     에너지산업 연소     경유       7461.07434       962.89413      6148.01742
# 6     에너지산업 연소     등유      17457.55016      5233.74347     14384.91268
# 7     에너지산업 연소    LPG       8192.23285      8192.23285      8192.23285
# 8     에너지산업 연소    LNG     904336.83188    904336.83188    904336.83188
# 9     에너지산업 연소   고형연료      46140.72419     34726.59513      42308.6963
# 10    에너지산업 연소     기타     140556.24992             NaN             NaN
# 11      비산업 연소    무연탄     306000.03018    122247.01234    234702.02196
# 12      비산업 연소   B-A유      24664.14195     13813.08599     22617.01783
# ...

# %%
df_pollution = px.data.gapminder().query("'대분류' == '에너지산업 연소'")
# 
data = go.Bar(x=df_pollution['소분류'], y=df_pollution['TSP'])
# x축 연도, y축 인구수, Bar 클래스 생성
layout = go.Layout(title='Pollution')
# Title 설정 
# 막대 그래프(Bar Chart, 바 차트)를 포함하는
# Figure 생성
fig = go.Figure(data=data, layout=layout) 
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 df_pollution = px.data.gapminder().query("'대분류' == '에너지산업 연소'")
#       2 #
#       3 data = go.Bar(x=df_pollution['소분류'], y=df_pollution['TSP'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4443, in DataFrame.query(self, expr, inplace, **kwargs)
#    4440 res = self.eval(expr, **kwargs)
#    4442 try:
# -> 4443     result = self.loc[res]
#    4444 except ValueError:
#    4445     # when res is multi-dimensional loc raises, but this is sometimes a
#    4446     # valid query
#    4447     result = self[res]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...
